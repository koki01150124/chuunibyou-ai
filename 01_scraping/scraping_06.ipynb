# %%
# !pip install requests
# !pip install lxml
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)

# %%
import requests
import lxml.html

# %%
url = "https://www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95"
response = requests.get(url)

response.encoding = response.apparent_encoding

print(response.text)
# Out:
# <!DOCTYPE html>
# <html
#   lang="ja"
#
# data-admin-domain="//blog.hatena.ne.jp"
# data-admin-origin="https://blog.hatena.ne.jp"
# data-author="harukazu1"
# data-avail-langs="ja en"
# data-blog="harukazu1.hatenablog.com"
# data-blog-comments-top-is-new="1"
# data-blog-host="harukazu1.hatenablog.com"
# data-blog-is-public="1"
# data-blog-name="コエノミカタ｜はるえるブログ"
# data-blog-owner="harukazu1"
# data-blog-show-ads=""
# data-blog-show-sleeping-ads=""
# data-blog-uri="https://www.haruelf.com/"
# data-blog-uuid="17391345971616627328"
# data-blogs-uri-base="https://www.haruelf.com"
# data-brand="pro"
# data-data-layer="{&quot;hatenablog&quot;:{&quot;admin&quot;:{},&quot;analytics&quot;:{&quot;brand_property_id&quot;:&quot;&quot;,&quot;measurement_id&quot;:&quot;G-9074M6E99F&quot;,&quot;non_sampling_property_id&quot;:&quot;&quot;,&quot;property_id&quot;:&quot;UA-135917178-1&quot;,&quot;separated_property_id&quot;:&quot;UA-29716941-23&quot;},&quot;blog&quot;:{&quot;blog_id&quot;:&quot;17391345971616627328&quot;,&quot;content_seems_japanese&quot;:&quot;true&quot;,&quot;disable_ads&quot;:&quot;custom_domain&quot;,&quot;enable_ads&quot;:&quot;false&quot;,&quot;enable_keyword_link&quot;:&quot;false&quot;,&quot;entry_show_footer_related_entries&quot;:&quot;true&quot;,&quot;force_pc_view&quot;:&quot;true&quot;,&quot;is_public&quot;:&quot;true&quot;,&quot;is_responsive_view&quot;:&quot;true&quot;,&quot;is_sleeping&quot;:&quot;false&quot;,&quot;lang&quot;:&quot;ja&quot;,&quot;name&quot;:&quot;\u30b3\u30a8\u30ce\u30df\u30ab\u30bf\uff5c\u306f\u308b\u3048\u308b\u30d6\u30ed\u30b0&quot;,&quot;owner_name&quot;:&quot;harukazu1&quot;,&quot;uri&quot;:&quot;https://www.haruelf.com/&quot;},&quot;brand&quot;:&quot;pro&quot;,&quot;page_id&quot;:&quot;entry&quot;,&quot;permalink_entry&quot;:{&quot;author_name&quot;:&quot;harukazu1&quot;,&quot;categories&quot;:&quot;\u30bb\u30ea\u30d5\u96c6\t\u7537\u6027\u5411\u3051\u30bb\u30ea\u30d5\u96c6\t\u5973\u6027\u5411\u3051\u30bb\u30ea\u30d5\u96c6&quot;,&quot;character_count&quot;:2452,&quot;date&quot;:&quot;2025-04-26&quot;,&quot;entry_id&quot;:&quot;6802418398374887879&quot;,&quot;first_category&quot;:&quot;\u30bb\u30ea\u30d5\u96c6&quot;,&quot;hour&quot;:&quot;12&quot;,&quot;title&quot;:&quot;\u3010\u611b\u3092\u4f1d\u3048\u305f\u3044\u53a8\u4e8c\u75c5\u30bb\u30ea\u30d5\u96c6\u2465\u3011\u604b\u611b\u306e\u4e2d\u4e8c\u75c5\u30bb\u30ea\u30d5 \u7f70\u30b2\u30fc\u30e0\u3084\u7df4\u7fd2\u306b\u4f7f\u3044\u3044\u305f\u3060\u3051\u307e\u3059\uff01&quot;,&quot;uri&quot;:&quot;https://www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95&quot;},&quot;pro&quot;:&quot;pro&quot;,&quot;router_type&quot;:&quot;blogs&quot;}}"
# data-device="pc"
# data-dont-recommend-pro="false"
# data-global-domain="https://hatena.blog"
# data-globalheader-color="b"
# data-globalheader-type="pc"
# data-has-touch-view="1"
# data-help-url="https://help.hatenablog.com"
# data-no-suggest-touch-view="1"
# data-page="entry"
# data-parts-domain="https://hatenablog-parts.com"
# data-plus-available="1"
# data-pro="true"
# data-router-type="blogs"
# data-sentry-dsn="https://03a33e4781a24cf2885099fed222b56d@sentry.io/1195218"
# data-sentry-environment="production"
# data-sentry-sample-rate="0.1"
# data-static-domain="https://cdn.blog.st-hatena.com"
# data-version="abf96f4605410ec3d67a4284c01b45"
#
#
#
#
#   data-initial-state="{}"
#
#   >
#   <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
#
#
#
#
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#
#
#
#
#
#
#
#   <meta name="robots" content="max-image-preview:large" />
#
#
#   <meta charset="utf-8"/>
#   <meta http-equiv="X-UA-Compatible" content="IE=7; IE=9; IE=10; IE=11" />
#   <title>【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ</title>
#
#
#   <link rel="canonical" href="https://www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95"/>
#
#
#
#
#
# <meta itemprop="name" content="【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ"/>
#
#   <meta itemprop="image" content="https://cdn.image.st-hatena.com/image/scale/1075ac5386c3fd388badf887724e05029aa62aab/backend=imagemagick;version=1;width=1300/https%3A%2F%2Fcdn-ak.f.st-hatena.com%2Fimages%2Ffotolife%2Fh%2Fharukazu1%2F20190719%2F20190719004333.jpg"/>
#
#
#   <meta property="og:title" content="【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ"/>
# <meta property="og:type" content="article"/>
#   <meta property="og:url" content="https://www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95"/>
#
#   <meta property="og:image" content="https://cdn.image.st-hatena.com/image/scale/1075ac5386c3fd388badf887724e05029aa62aab/backend=imagemagick;version=1;width=1300/https%3A%2F%2Fcdn-ak.f.st-hatena.com%2Fimages%2Ffotolife%2Fh%2Fharukazu1%2F20190719%2F20190719004333.jpg"/>
#
# <meta property="og:image:alt" content="【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ"/>
#     <meta property="og:description" content="愛を伝えたい厨二病セリフ集です！ 罰ゲームや練習、演技の投稿などご自由にお使いください！ 短い文章は状況や相手を変えるだけで大きく意味合いや言い方が変わってきます！！今回はそんな面白い短文のセリフ集を作らせていただきました！これらのサンプル用のセリフは遊ぶ気分で楽しく読んでもらったらいいなと思います！ ※無断での商用利用、または他サイトへの転載は厳禁です。商用利用についてはこちら ※配信セリフ枠・セリフ動画投稿・ボイスサンプルなど個人の使用に関してご自由にお使いいただけます。※使用報告はなくても大丈夫ですが、コメントへしていただけると、今後の活動の励みになります！※このセリフ集はフィクションで…" />
# <meta property="og:site_name" content="コエノミカタ｜はるえるブログ"/>
#
#   <meta property="article:published_time" content="2025-04-26T03:40:12Z" />
#
#     <meta property="article:tag" content="セリフ集" />
#     <meta property="article:tag" content="男性向けセリフ集" />
#     <meta property="article:tag" content="女性向けセリフ集" />
#       <meta name="twitter:card"  content="summary_large_image" />
#     <meta name="twitter:image" content="https://cdn.image.st-hatena.com/image/scale/1075ac5386c3fd388badf887724e05029aa62aab/backend=imagemagick;version=1;width=1300/https%3A%2F%2Fcdn-ak.f.st-hatena.com%2Fimages%2Ffotolife%2Fh%2Fharukazu1%2F20190719%2F20190719004333.jpg" />  <meta name="twitter:title" content="【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ" />    <meta name="twitter:description" content="愛を伝えたい厨二病セリフ集です！ 罰ゲームや練習、演技の投稿などご自由にお使いください！ 短い文章は状況や相手を変えるだけで大きく意味合いや言い方が変わってきます！！今回はそんな面白い短文のセリフ集を作らせていただきました！これらのサンプル用のセリフは遊ぶ気分で楽しく読んでもらったらいいなと思います！ ※無断での商用利…" />  <meta name="twitter:app:name:iphone" content="はてなブログアプリ" />
#   <meta name="twitter:app:id:iphone" content="583299321" />
#   <meta name="twitter:app:url:iphone" content="hatenablog:///open?uri=https%3A%2F%2Fwww.haruelf.com%2Fentry%2F%25E5%258E%25A8%25E4%25BA%258C%25E7%2597%2585_%25E6%2584%259B%25E3%2582%25BB%25E3%2583%25AA%25E3%2583%2595" />  <meta name="twitter:site" content="@HaruELF_HP" />
#
#     <meta name="description" content="愛を伝えたい厨二病セリフ集です！ 罰ゲームや練習、演技の投稿などご自由にお使いください！ 短い文章は状況や相手を変えるだけで大きく意味合いや言い方が変わってきます！！今回はそんな面白い短文のセリフ集を作らせていただきました！これらのサンプル用のセリフは遊ぶ気分で楽しく読んでもらったらいいなと思います！ ※無断での商用利用、または他サイトへの転載は厳禁です。商用利用についてはこちら ※配信セリフ枠・セリフ動画投稿・ボイスサンプルなど個人の使用に関してご自由にお使いいただけます。※使用報告はなくても大丈夫ですが、コメントへしていただけると、今後の活動の励みになります！※このセリフ集はフィクションで…" />
#     <meta name="google-site-verification" content="xlXnn6GRQk-gpFYrMyuKK7jFTzIsMIPH5ANrjKV5jX8" />
#     <meta name="keywords" content="&lt;meta name=&quot;keywords&quot;content=&quot;声優&quot;&gt;" />
#
#
#
# <script
#   id="embed-gtm-data-layer-loader"
#   data-data-layer-page-specific="{&quot;hatenablog&quot;:{&quot;blogs_permalink&quot;:{&quot;blog_afc_issued&quot;:&quot;false&quot;,&quot;entry_afc_issued&quot;:&quot;false&quot;,&quot;is_author_pro&quot;:&quot;true&quot;,&quot;is_blog_sleeping&quot;:&quot;false&quot;,&quot;has_related_entries_with_elasticsearch&quot;:&quot;true&quot;}}}"
# >
# (function() {
#   function loadDataLayer(elem, attrName) {
#     if (!elem) { return {}; }
#     var json = elem.getAttribute(attrName);
#     if (!json) { return {}; }
#     return JSON.parse(json);
#   }
#
#   var globalVariables = loadDataLayer(
#     document.documentElement,
#     'data-data-layer'
#   );
#   var pageSpecificVariables = loadDataLayer(
#     document.getElementById('embed-gtm-data-layer-loader'),
#     'data-data-layer-page-specific'
#   );
#
#   var variables = [globalVariables, pageSpecificVariables];
#
#   if (!window.dataLayer) {
#     window.dataLayer = [];
#   }
#
#   for (var i = 0; i < variables.length; i++) {
#     window.dataLayer.push(variables[i]);
#   }
# })();
# </script>
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P4CXTW');</script>
# <!-- End Google Tag Manager -->
#
#
#
#
#
#
#
#
#
#
#
#   <link rel="shortcut icon" href="https://www.haruelf.com/icon/favicon">
# <link rel="apple-touch-icon" href="https://www.haruelf.com/icon/touch">
# <link rel="icon" sizes="192x192" href="https://www.haruelf.com/icon/link">
#
#
#
# <link rel="alternate" type="application/atom+xml" title="Atom" href="https://www.haruelf.com/feed"/>
# <link rel="alternate" type="application/rss+xml" title="RSS2.0" href="https://www.haruelf.com/rss"/>
#
#   <link rel="alternate" type="application/json+oembed" href="https://hatena.blog/oembed?url=https%3A%2F%2Fwww.haruelf.com%2Fentry%2F%25E5%258E%25A8%25E4%25BA%258C%25E7%2597%2585_%25E6%2584%259B%25E3%2582%25BB%25E3%2583%25AA%25E3%2583%2595&amp;format=json" title="oEmbed Profile of 【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！"/>
# <link rel="alternate" type="text/xml+oembed" href="https://hatena.blog/oembed?url=https%3A%2F%2Fwww.haruelf.com%2Fentry%2F%25E5%258E%25A8%25E4%25BA%258C%25E7%2597%2585_%25E6%2584%259B%25E3%2582%25BB%25E3%2583%25AA%25E3%2583%2595&amp;format=xml" title="oEmbed Profile of 【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！"/>
#
#   <link rel="author" href="http://www.hatena.ne.jp/harukazu1/">
#
#
#
#
#       <link rel="preload" href="https://cdn-ak.f.st-hatena.com/images/fotolife/h/harukazu1/20190719/20190719004333.jpg" as="image"/>
#
#
#
#
# <link rel="stylesheet" type="text/css" href="https://cdn.blog.st-hatena.com/css/blog.css?version=abf96f4605410ec3d67a4284c01b45"/>
#
#
#   <link rel="stylesheet" type="text/css" href="https://usercss.blog.st-hatena.com/blog_style/17391345971616627328/8142c041083059ff44ee653ce75849d972d59a65"/>
#
#
#
#
#
#
# <script> </script>
#
#
# <style>
#   div#google_afc_user,
#   div.google-afc-user-container,
#   div.google_afc_image,
#   div.google_afc_blocklink {
#       display: block !important;
#   }
# </style>
#
#
#
#
#
#     <script type="application/ld+json">{"@context":"http://schema.org","@type":"Article","dateModified":"2025-11-29T16:32:27+09:00","datePublished":"2025-04-26T12:40:12+09:00","headline":"【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！","image":["https://cdn-ak.f.st-hatena.com/images/fotolife/h/harukazu1/20190719/20190719004333.jpg"]}</script>
#
#
#
#   <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-135917178-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-135917178-1');
# </script>
# </head>
#
#   <body class="page-entry enable-top-editarea enable-bottom-editarea category-セリフ集 category-男性向けセリフ集 category-女性向けセリフ集 globalheader-ng-enabled">
#
#
# <div id="globalheader-container"
#   data-brand="hatenablog"
#
#   >
#   <iframe id="globalheader" height="37" frameborder="0" allowTransparency="true"></iframe>
# </div>
#
#
#
#
#
#     <nav class="
#       blog-controlls
#
#     ">
#       <div class="blog-controlls-blog-icon">
#         <a href="https://www.haruelf.com/">
#           <img src="https://cdn.image.st-hatena.com/image/square/ca4a2edd1613bae586d27eae91080e3945cd9458/backend=imagemagick;height=128;version=1;width=128/https%3A%2F%2Fcdn.user.blog.st-hatena.com%2Fblog_custom_icon%2F151169385%2F1747663642437164" alt="コエノミカタ｜はるえるブログ"/>
#         </a>
#       </div>
#       <div class="blog-controlls-title">
#         <a href="https://www.haruelf.com/">コエノミカタ｜はるえるブログ</a>
#       </div>
#       <a href="https://blog.hatena.ne.jp/harukazu1/harukazu1.hatenablog.com/subscribe?utm_campaign=subscribe_blog&amp;utm_medium=button&amp;utm_source=blogs_topright_button" class="blog-controlls-subscribe-btn test-blog-header-controlls-subscribe">
#         読者になる
#       </a>
#     </nav>
#
#
#   <div id="container">
#     <div id="container-inner">
#       <header id="blog-title" data-brand="hatenablog">
#   <div id="blog-title-inner" >
#     <div id="blog-title-content">
#       <h1 id="title"><a href="https://www.haruelf.com/">コエノミカタ｜はるえるブログ</a></h1>
#
#         <h2 id="blog-description">演技が好きな全ての方へ！フリーで使えるセリフ集・ボイスサンプル・台本などをメインで投稿しています！</h2>
#
#     </div>
#   </div>
# </header>
#
#
#   <div id="top-editarea">
#     <nav id="slide-nav">
# <div class="slide-nav-inner" id="menu-scroll">
#     <div class="menu"><a href="https://www.haruelf.com/entry/serifusyu/matome/"><i class="fa fa-home fa-fw" style="font-size:1em;"></i>HOME</a></div>
# <div class="menu"><a href="https://www.haruelf.com/archive/category/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86"><i class="fa fa-wrench fa-fw" style="font-size:1em;"></i>セリフ集</div>
# <div class="menu"><a href="https://www.haruelf.com/archive/category/%E7%94%B7%E6%80%A7%E5%90%91%E3%81%91%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86#google_vignette"><i class="fa fa-wrench fa-fw" style="font-size:1em;"></i>男性向けセリフ集</div>
# <div class="menu"><a href="https://www.haruelf.com/archive/category/%E5%A5%B3%E6%80%A7%E5%90%91%E3%81%91%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86"><i class="fa fa-wrench fa-fw" style="font-size:1em;"></i>女性向けセリフ集</div>
# <div class="menu"><a href="https://www.haruelf.com/archive/category/%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BC%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86"><i class="fa fa-wrench fa-fw" style="font-size:1em;"></i>ファンタジーセリフ集</div>
# <div class="menu"><a href="https://www.haruelf.com/archive/category/%E3%82%BB%E3%83%AA%E3%83%95"><i class="fa fa-bolt fa-fw" style="font-size:1em;"></i>セリフ</a></div>
# <div class="menu"><a href="https://www.haruelf.com/archive/category/%E6%BB%91%E8%88%8C%E7%B7%B4%E7%BF%92"><i class="fas fa-check fa-fw" style="font-size:1em;"></i>滑舌・発声練習</a></div>
# <div class="menu"><a href="https://www.haruelf.com/archive/category/%E3%83%96%E3%83%AD%E3%82%B0"><i class="fa fa-book fa-fw" style="font-size:1em;"></i>その他</a></div>
# </div>
# </nav>
# <link type=”text/css” rel=”stylesheet” href=”http://hatena.wackwack.net/v1.1/css/fulldisplay.min.css“/>
# <p style="text-align:center "><span style="font-size: 80%; color: #666666;">
# 本サイトは運営の為、アフェリエイト広告を利用しております。ご了承ください。
# </p>
#   </div>
#
#
#
#           <div id="top-box">
#     <div class="breadcrumb" data-test-id="breadcrumb">
#       <div class="breadcrumb-inner">
#         <a class="breadcrumb-link" href="https://www.haruelf.com/"><span>トップ</span></a>          <span class="breadcrumb-gt">&gt;</span>          <span class="breadcrumb-child">            <a class="breadcrumb-child-link" href="https://www.haruelf.com/archive/category/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86"><span>セリフ集</span></a>          </span>            <span class="breadcrumb-gt">&gt;</span>          <span class="breadcrumb-child">            <span>【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！</span>          </span>      </div>
#     </div>
#   </div>
#   <script type="application/ld+json" class="test-breadcrumb-json-ld">
#     {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"item":{"name":"トップ","@id":"https://www.haruelf.com/"},"@type":"ListItem","position":1},{"position":2,"item":{"name":"セリフ集","@id":"https://www.haruelf.com/archive/category/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86"},"@type":"ListItem"}]}
#   </script>
#
#
#
#
#
#
# <div id="content" class="hfeed"
#
#   >
#   <div id="content-inner">
#     <div id="wrapper">
#       <div id="main">
#         <div id="main-inner">
#
#
#
#
#
#
#
#
#   <!-- google_ad_section_start -->
#   <!-- rakuten_ad_target_begin -->
#
#
#
#
#
#
#
#
#
#         <article class="entry hentry test-hentry js-entry-article date-first autopagerize_page_element chars-2800 words-200 mode-html entry-odd" id="entry-6802418398374887879" data-keyword-campaign="" data-uuid="6802418398374887879" data-publication-type="entry">
#   <div class="entry-inner">
#     <header class="entry-header">
#
#     <div class="date entry-date first">
#     <a href="https://www.haruelf.com/archive/2025/04/26" rel="nofollow">
#       <time datetime="2025-04-26T03:40:12Z" title="2025-04-26T03:40:12Z">
#         <span class="date-year">2025</span><span class="hyphen">-</span><span class="date-month">04</span><span class="hyphen">-</span><span class="date-day">26</span>
#       </time>
#     </a>
#           <span class="date-last-updated test-display-last-updated">
#         <?xml version="1.0" encoding="UTF-8"?><svg id="uuid-e3102712-05f4-4764-adf9-29a79fcac50f" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24" class="blogicon" role="img" aria-label="最終更新日"><g id="uuid-e023a8e5-d6b4-4344-9935-7fe8a32ac06e"><title>最終更新日</title><path d="m12,3.99c2.35,0,4.54,1.04,6.04,2.78h-2.47v1.7h5.81V2.66h-1.7v2.96c-1.88-2.26-4.68-3.63-7.68-3.63C6.48,1.99,1.99,6.48,1.99,12h2C3.99,7.58,7.59,3.99,12,3.99Z"/><path d="m20.01,12c0,4.42-3.59,8.01-8.01,8.01-2.35,0-4.54-1.04-6.04-2.78h2.47v-1.7H2.61v5.81h1.7v-2.96c1.88,2.26,4.68,3.63,7.68,3.63,5.52,0,10.01-4.49,10.01-10.01h-2Z"/></g></svg>
#
#         <time itemprop="dateModified" datetime="2025-09-08T14:21:36Z" title="2025-09-08T14:21:36Z">
#           <span class="date-year">2025</span><span class="hyphen">-</span><span class="date-month">09</span><span class="hyphen">-</span><span class="date-day">08</span>
#         </time>
#       </span>  </div>
#   <h1 class="entry-title">
#   <a href="https://www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95" class="entry-title-link bookmark">【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！</a>
# </h1>
#
#
#
#
#   <div class="entry-categories categories">
#
#     <a href="https://www.haruelf.com/archive/category/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86" class="entry-category-link category-セリフ集">セリフ集</a>
#
#     <a href="https://www.haruelf.com/archive/category/%E7%94%B7%E6%80%A7%E5%90%91%E3%81%91%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86" class="entry-category-link category-男性向けセリフ集">男性向けセリフ集</a>
#
#     <a href="https://www.haruelf.com/archive/category/%E5%A5%B3%E6%80%A7%E5%90%91%E3%81%91%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86" class="entry-category-link category-女性向けセリフ集">女性向けセリフ集</a>
#
#   </div>
#
#
#
#
#
#
# </header>
#
#
#
#
#     <div class="entry-content hatenablog-entry">
#
#     <p>愛を伝えたい厨二病セリフ集です！</p>
# <p>罰ゲームや練習、演技の投稿などご自由にお使いください！</p>
# <p><img class="hatena-fotolife" src="https://cdn-ak.f.st-hatena.com/images/fotolife/h/harukazu1/20190719/20190719004333.jpg" border="0" alt="f:id:harukazu1:20190719004333j:image" title="f:id:harukazu1:20190719004333j:image" loading="lazy" /></p>
# <p>短い文章は状況や相手を変えるだけで大きく意味合いや言い方が変わってきます！！<br />今回はそんな面白い短文のセリフ集を作らせていただきました！<br />これらのサンプル用のセリフは遊ぶ気分で楽しく読んでもらったらいいなと思います！</p>
# <p><span style="color: #62c7c9; font-size: 80%;">※無断での商用利用、または他サイトへの転載は厳禁です。商用利用については<a style="color: #62c7c9;" href="https://www.haruelf.com/%E3%82%BB%E3%83%AA%E3%83%95%E5%88%A9%E7%94%A8%E8%A6%8F%E7%B4%84">こちら</a><a style="color: #62c7c9;" href="https://www.haruelf.com/%E3%82%BB%E3%83%AA%E3%83%95%E5%88%A9%E7%94%A8%E8%A6%8F%E7%B4%84"> </a><br /></span><span style="color: #62c7c9; font-size: 80%;">※配信セリフ枠・セリフ動画投稿・ボイスサンプルなど個人の使用に関してご自由にお使いいただけます。<br /></span><span style="color: #62c7c9; font-size: 80%;">※使用報告はなくても大丈夫ですが、コメントへしていただけると、今後の活動の励みになります！<br /></span><span style="color: #62c7c9; font-size: 80%;">※このセリフ集はフィクションです。実際の人物、団体などとは関係ありません。<br /></span><span style="color: #62c7c9; font-size: 80%;">※本サイトは運営の為、広告などのプロモーションを扱っております。ご了承ください。<br /></span></p>
# <p style="text-align: center;"><span style="font-size: 80%; color: #62c7c9;"><a style="color: #62c7c9;" href="https://www.haruelf.com/%E3%82%BB%E3%83%AA%E3%83%95%E5%88%A9%E7%94%A8%E8%A6%8F%E7%B4%84">-セリフ使用に関する利用規約-</a></span></p>
# <p>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1217217413601760" crossorigin="anonymous"></script>
# </p>
#
# <p>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </p>
# <p><iframe src="https://blog.hatena.ne.jp/harukazu1/harukazu1.hatenablog.com/subscribe/iframe" width="150" height="28" frameborder="0" scrolling="no"></iframe></p>
# <p>【目次】</p>
# <ul class="table-of-contents">
#     <li><a href="#1中二病一生大切にする">1中二病　一生大切にする</a></li>
#     <li><a href="#2中二病君の事が好きだ">2中二病　君の事が好きだ</a></li>
#     <li><a href="#3中二病お幸せに">3中二病　お幸せに</a></li>
#     <li><a href="#4中二病生まれ変わっても">4中二病　生まれ変わっても</a></li>
#     <li><a href="#5中二病一緒についてきてくれ">5中二病　一緒についてきてくれ</a></li>
#     <li><a href="#6中二病フラれた">6中二病　フラれた</a></li>
#     <li><a href="#7中二病返事ありがとう">7中二病　返事ありがとう</a></li>
#     <li><a href="#8中二病永遠の別れ">8中二病　永遠の別れ</a></li>
#     <li><a href="#9中二病告白を見守る">9中二病　告白を見守る。</a></li>
#     <li><a href="#10中二病一歩踏み出すことが大切">10中二病　一歩踏み出すことが大切。</a></li>
#     <li><a href="#11中二病恋人がほしい人には恋人は出来ない">11中二病　恋人がほしい人には恋人は出来ない</a></li>
#     <li><a href="#12中二病心のざわめき">12中二病　心のざわめき</a></li>
#     <li><a href="#13中二病先に譲る">13中二病　先に譲る</a></li>
#     <li><a href="#14中二病一途な心">14中二病　一途な心</a></li>
#     <li><a href="#15中二病大切な物は失ってから気づく">15中二病　大切な物は失ってから気づく</a></li>
# </ul>
# <p> </p>
# <p>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1217217413601760" crossorigin="anonymous"></script>
#  <ins class="adsbygoogle" style="display: block;" data-ad-client="ca-pub-1217217413601760" data-ad-slot="9031778214" data-ad-format="auto" data-full-width-responsive="true"> </ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </p>
# <p> </p>
# <h3 id="1中二病一生大切にする">1中二病　一生大切にする</h3>
# <p>この身が朽ち果てようとも、</p>
# <p>君の事を永遠（とわ）に護る──それが俺の“契約”だ。</p>
# <p><span style="color: #00cccc;">（訳：一生大切にする</span><span style="color: #00cccc;">）</span></p>
# <p> </p>
# <h3 id="2中二病君の事が好きだ">2中二病　君の事が好きだ</h3>
# <p>愛している、なんて言葉じゃ足りない。</p>
# <p>俺の魂ごと貴様に捧げよう。</p>
# <p><span style="color: #00cccc;">（訳：君のことが好きだ）</span></p>
# <p> </p>
# <h3 id="3中二病お幸せに">3中二病　お幸せに</h3>
# <p>一途な心は、時に世界をも変える。</p>
# <p>お前、あいつを絶対に幸福にするんんだな。</p>
# <p>愛に全力を注げ。</p>
# <p> </p>
# <p><span style="color: #00cccc;">（訳：お幸せに）</span></p>
# <p> </p>
# <h3 id="4中二病生まれ変わっても">4中二病　生まれ変わっても</h3>
# <p>生まれ変わっても、運命に逆らったとしても、俺はまた君を選ぶ。</p>
# <p>どうか生きてくれ。</p>
# <p><span style="color: #00cccc;">（訳：生まれ変わっても愛している）</span></p>
# <p> </p>
# <h3 id="5中二病一緒についてきてくれ">5中二病　一緒についてきてくれ</h3>
# <p>そんな悲しい運命なんて俺が撃ち砕く。</p>
# <p>共に行こう。さぁ手を。</p>
# <p><span style="color: #00cccc;">（訳：一緒についてきてくれ）</span></p>
# <p> </p>
# <p>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1217217413601760" crossorigin="anonymous"></script>
#  <ins class="adsbygoogle" style="display: block;" data-ad-client="ca-pub-1217217413601760" data-ad-slot="1269595156" data-ad-format="auto" data-full-width-responsive="true"> </ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </p>
# <p> </p>
# <h3 id="6中二病フラれた">6中二病　フラれた</h3>
# <p>…そうか、それがあなたの選んだ選択か。</p>
# <p>ならば、俺はもう干渉しない。だが常にあなたの味方だ。</p>
# <p>困った時があればいつでも言ってくれ。</p>
# <p><span style="color: #00cccc;">（訳：フラれた。付き合うのは無理だと思うけど困ったら力になる）</span></p>
# <p> </p>
# <h3 id="7中二病返事ありがとう">7中二病　返事ありがとう</h3>
# <p>ありがとう。</p>
# <p>ほんの少しでも、俺を見てくれたことに感謝する。</p>
# <p><span style="color: #00cccc;">（訳：返事ありがとう）</span></p>
# <p> </p>
# <h3 id="8中二病永遠の別れ">8中二病　永遠の別れ</h3>
# <p>君がいない世界なんて、色を失った幻想だ。</p>
# <p>俺はこれからどうしたらいいんだ...</p>
# <p>なぁ答えてくれ...よ</p>
# <p><span style="color: #00cccc;">（訳：恋人と永遠の別れ）</span></p>
# <p> </p>
# <h3 id="9中二病告白を見守る">9中二病　告白を見守る。</h3>
# <p>俺の役目は...見届けることだ。</p>
# <p>あの美しい心を手にするその“瞬間”を。</p>
# <p><span style="color: #00cccc;">（訳：告白を見守る。応援してるよ。）</span></p>
# <p> </p>
# <h3 id="10中二病一歩踏み出すことが大切">10中二病　一歩踏み出すことが大切。</h3>
# <p>俺の心が叫んでいるんだ！</p>
# <p>最高のエンディングをむかえろと！</p>
# <p>立て！まだ君はチャレンジしていないんだ！</p>
# <p><span style="color: #00cccc;">（訳：諦めずにまずは一歩踏み出すことがすることが大切）</span></p>
# <p>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1217217413601760" crossorigin="anonymous"></script>
# </p>
#
# <p>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </p>
# <p> </p>
# <p>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1217217413601760" crossorigin="anonymous"></script>
#  <ins class="adsbygoogle" style="display: block;" data-ad-client="ca-pub-1217217413601760" data-ad-slot="1269595156" data-ad-format="auto" data-full-width-responsive="true"> </ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </p>
# <p> </p>
# <h3 id="11中二病恋人がほしい人には恋人は出来ない">11中二病　恋人がほしい人には恋人は出来ない</h3>
# <p>ジレンマがある。</p>
# <p>恋人がほしい奴に、恋人は出来ない。</p>
# <p>まずは己の目標や夢に向けて全力で努力せよ。</p>
# <p>つまりやることをちゃんとやれ。</p>
# <p>アプローチをするのはそれからだ。</p>
# <p><span style="color: #00cccc;">（訳：恋人を求めるな。まずはやるべきことをやる、そして何かに夢中になれ。）</span></p>
# <p> </p>
# <h3 id="12中二病心のざわめき">12中二病　心のざわめき</h3>
# <p>心がざわめく。</p>
# <p>この感情は何だ。</p>
# <p>求めていたもの、握るべきは栄光のはず。</p>
# <p>なんだ？この感情は...！！！</p>
# <p><span style="color: #00cccc;">（訳：もしかして恋している？）</span></p>
# <p> </p>
# <h3 id="13中二病先に譲る">13中二病　先に譲る</h3>
# <p>貴様の行いに一度だけ、目をつぶり、俺は静かに見守る。</p>
# <p>決して、邪魔はしないと誓う。</p>
# <p>だが一度きりだ。</p>
# <p><span style="color: #00cccc;">（訳：告白は先に譲る）</span></p>
# <p> </p>
# <h3 id="14中二病一途な心">14中二病　一途な心</h3>
# <p>一途な心は、時に世界をも変える。</p>
# <p>その想いが本物なら大丈夫であろう。</p>
# <p>もし偽りなら、その後に待っているのは破滅だ。</p>
# <p><span style="color: #00cccc;">（訳：一途な心が大切）</span></p>
# <p> </p>
# <h3 id="15中二病大切な物は失ってから気づく">15中二病　大切な物は失ってから気づく</h3>
# <p>慣れは恐怖だ。</p>
# <p>大切な物なら大切にしまっておけ。</p>
# <p>人は失ってからその大切さに気付く。</p>
# <p>貴様は...後悔したいのか？</p>
# <p><span style="color: #00cccc;">（訳：大切な物は失ってから気づくから大切にしようね）</span></p>
# <p> </p>
# <p> </p>
# <p style="text-align: center;"><a href="https://www.haruelf.com/entry/serif/5">≪前の記事</a>　<a href="https://www.haruelf.com/entry/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E4%B8%80%E8%A6%A7/%E4%B8%AD%E4%BA%8C%E7%97%85">一覧</a>　<span style="color: #999999;">次の記事≫</span></p>
# <p> </p>
# <p style="text-align: center;"><span style="font-size: 150%;"><strong>最後までご覧いただきありがとうございました！</strong></span></p>
# <p style="text-align: center;">🔗<strong> 関連記事はこちらから！</strong></p>
# <p>　🎤<strong>セリフ練習におすすめ</strong></p>
# <ul>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%AB/%E7%94%B7%E6%80%A7%E5%90%91%E3%81%91/%E3%82%BB%E3%83%AA%E3%83%95%E5%8F%B0%E6%9C%AC" style="color: #2196f3; text-decoration: underline;">男性向けセリフ集まとめ</a></span></li>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%AB/%E5%A5%B3%E6%80%A7%E5%90%91%E3%81%91%E3%82%BB%E3%83%AA%E3%83%95%E5%8F%B0%E6%9C%AC" style="color: #2196f3; text-decoration: underline;">女性向けセリフ集まとめ</a></span></li>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E4%B8%80%E8%A6%A7/%E4%B8%AD%E4%BA%8C%E7%97%85" style="color: #2196f3; text-decoration: underline;">中二病・厨二病 のセリフ集まとめ</a></span></li>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E4%B8%80%E8%A6%A7/%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BC/" style="color: #2196f3; text-decoration: underline;">ファンタジー系のセリフ集まとめ</a></span></li>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%AB/%E5%BF%85%E6%AE%BA%E6%8A%80%EF%BC%86%E9%AD%94%E6%B3%95" style="color: #2196f3; text-decoration: underline;">必殺技＆魔法＆詠唱のセリフ集まとめ</a></span></li>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/%E5%A4%96%E7%94%BB%E5%90%B9%E3%81%8D%E6%9B%BF%E3%81%88%E9%A2%A8%E3%81%AE%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E3%81%BE%E3%81%A8%E3%82%81" style="color: #2196f3; text-decoration: underline;">外画吹き替え風のセリフ集まとめ</a></span></li>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/emotion/serif" style="color: #2196f3; text-decoration: underline;">感情別セリフ集まとめ</a></span></li>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/%E6%81%8B%E6%84%9B%E7%B3%BB%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E3%81%BE%E3%81%A8%E3%82%81" style="color: #2196f3; text-decoration: underline;">恋愛系セリフ集まとめ</a></span></li>
# <li><span style="text-decoration: underline; color: #2196f3;"><a href="https://www.haruelf.com/entry/%E8%A8%AD%E5%AE%9A%E5%88%A5%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E3%81%BE%E3%81%A8%E3%82%81" style="color: #2196f3; text-decoration: underline;">設定別セリフ集まとめ</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/archive/category/%E7%BD%B0%E3%82%B2%E3%83%BC%E3%83%A0%E3%81%AB%E3%82%82%E4%BD%BF%E3%81%88%E3%82%8B%EF%BC%81" style="color: #2196f3;">罰ゲームにおすすめ！ちょっと恥ずかしいセリフ集まとめ</a></span></li>
# <li><a href="https://www.haruelf.com/entry/serifusyu/matome/"><span style="color: #2196f3;">セリフ集まとめ総集編</span></a>(トップページ)</li>
# </ul>
# <p>　🎙<strong>ナレーション練習におすすめ</strong></p>
# <ul>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%AB/%E3%83%8A%E3%83%AC%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3/%E7%B7%B4%E7%BF%92%E7%94%A8%E5%8F%B0%E6%9C%AC" style="color: #2196f3;">ナレーション 練習用台本まとめ</a></span></li>
# </ul>
# <p> 　🗣<strong> 滑舌・発声トレーニング向け</strong></p>
# <ul>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.k" style="color: #2196f3;">滑舌練習「か行」を鍛えよう！</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.%EF%BD%93" style="color: #2196f3;">滑舌練習「さ行」を鍛えよう！</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.%EF%BD%94" style="color: #2196f3;">滑舌練習「た行」を鍛えよう！</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.%EF%BD%8E" style="color: #2196f3;">滑舌練習「な行」を鍛えよう！</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.%EF%BD%88" style="color: #2196f3;">滑舌練習「は行」を鍛えよう！</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.%EF%BD%8D" style="color: #2196f3;">滑舌練習「ま行」を鍛えよう！</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.%EF%BD%99" style="color: #2196f3;">滑舌練習「や行」を鍛えよう！</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.%EF%BD%92" style="color: #2196f3;">滑舌練習「ら行」を鍛えよう！</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/tonguetwister/japan.%EF%BD%97" style="color: #2196f3;">滑舌練習「わ行」を鍛えよう！</a></span></li>
# </ul>
# <p>　🎹声劇台本（※２名以上の台本もこちら）</p>
# <ul>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/archive/category/%E5%A3%B0%E5%8A%87%E5%8F%B0%E6%9C%AC" style="color: #2196f3;">声劇台本 まとめ記事一覧</a></span></li>
# </ul>
# <p>　🎧<strong>業界用語を知りたい方におすすめ</strong></p>
# <ul>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/entry/%E7%94%A8%E8%AA%9E%E9%9B%86" style="color: #2196f3;">声優になるには知っておきたい用語集まとめ</a></span></li>
# </ul>
# <p><strong>　🖊オーディション対策におすすめ！</strong></p>
# <ul>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/archive/category/%E8%87%AA%E5%B7%B1PR" style="color: #2196f3;">自己PRについて</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/archive/category/%E3%83%A1%E3%83%B3%E3%82%BF%E3%83%AB%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6" style="color: #2196f3;">メンタルについて</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/archive/category/%E3%83%9C%E3%82%A4%E3%82%B9%E3%82%B5%E3%83%B3%E3%83%97%E3%83%AB%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6" style="color: #2196f3;">ボイスサンプルについて</a></span></li>
# <li><span style="color: #2196f3;"><a href="https://www.haruelf.com/archive/category/%E5%AE%A3%E6%9D%90%E5%86%99%E7%9C%9F%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6" style="color: #2196f3;">宣材写真について</a></span></li>
# </ul>
# <p>最後までご覧いただきありがとうございました！  <br />気になる記事があればぜひ読んでみてくださいね✨</p>
# <p> </p>
# <p><span style="font-size: 80%;">はてなブログさんのランキングにも参加しています！<br /></span><span style="font-size: 80%;">⇓クリックで応援お願いします！</span></p>
# <p><div class="embed-group"><a href="https://blog.hatena.ne.jp/-/group/11696248318754550861/redirect" class="embed-group-link js-embed-group-link"><div class="embed-group-icon"><img src="https://cdn.image.st-hatena.com/image/square/f2587dbad2c86fbaaa0b5bd0a9c312319f91c4c6/backend=imagemagick;height=80;version=1;width=80/https%3A%2F%2Fcdn.blog.st-hatena.com%2Fimages%2Fcircle%2Fofficial-circle-icon%2Fanimation-and-comics.gif" alt="" width="40" height="40"></div><div class="embed-group-content"><span class="embed-group-title-label">ランキング参加中</span><div class="embed-group-title">声優</div></div></a></div></p>
#
#
#
#
#
#
#
#
#
# </div>
#
#
#   <footer class="entry-footer">
#       <div class="entry-footer-modules" id="entry-footer-primary-modules">
# <div class="hatena-module hatena-module-entries-access-ranking"
#   data-count="5"
#   data-source="access"
#   data-enable_customize_format="0"
#   data-display_entry_image_size_width="100"
#   data-display_entry_image_size_height="100"
#
#   data-display_entry_category="1"
#   data-display_entry_image="1"
#   data-display_entry_image_size_width="100"
#   data-display_entry_image_size_height="100"
#   data-display_entry_body_length="0"
#   data-display_entry_date="0"
#   data-display_entry_title_length="20"
#   data-restrict_entry_title_length="0"
#   data-display_bookmark_count="0"
#
# >
#   <div class="hatena-module-title">
#
#       注目記事
#
#   </div>
#   <div class="hatena-module-body">
#
#   </div>
# </div>
#   </div>
#     <div class="entry-tags-wrapper">
#   <div class="entry-tags">
#       <span class="entry-tag">
#         <a href="https://d.hatena.ne.jp/keyword/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86" class="entry-tag-link">
#
#
#           <span class="entry-tag-icon">#</span><span class="entry-tag-label">セリフ集</span>
#         </a>
#       </span>
#
#       <span class="entry-tag">
#         <a href="https://d.hatena.ne.jp/keyword/%E3%83%9C%E3%82%A4%E3%82%B9%E3%82%B5%E3%83%B3%E3%83%97%E3%83%AB" class="entry-tag-link">
#
#
#           <span class="entry-tag-icon">#</span><span class="entry-tag-label">ボイスサンプル</span>
#         </a>
#       </span>
#       </div>
# </div>
#
#     <p class="entry-footer-section track-inview-by-gtm" data-gtm-track-json="{&quot;area&quot;: &quot;finish_reading&quot;}">
#   <span class="author vcard"><span class="fn" data-load-nickname="1" data-user-name="harukazu1" >harukazu1</span></span>
#   <span class="entry-footer-time"><a href="https://www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95"><time data-relative datetime="2025-04-26T03:40:12Z" title="2025-04-26T03:40:12Z" class="updated">2025-04-26 12:40</time></a></span>
#
#
#
#     <span class="
#       entry-footer-subscribe
#
#     " data-test-blog-controlls-subscribe>
#       <a href="https://blog.hatena.ne.jp/harukazu1/harukazu1.hatenablog.com/subscribe?utm_medium=button&amp;utm_source=blogs_entry_footer&amp;utm_campaign=subscribe_blog">
#         読者になる
#       </a>
#     </span>
#
# </p>
#
#
#   <div
#     class="hatena-star-container"
#     data-hatena-star-container
#     data-hatena-star-url="https://www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95"
#     data-hatena-star-title="【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！"
#     data-hatena-star-variant="profile-icon"
#     data-hatena-star-profile-url-template="https://blog.hatena.ne.jp/{username}/"
#   ></div>
#
#
#
# <div class="social-buttons">
#
#
#     <div class="social-button-item">
#       <a href="https://b.hatena.ne.jp/entry/s/www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95" class="hatena-bookmark-button" data-hatena-bookmark-url="https://www.haruelf.com/entry/%E5%8E%A8%E4%BA%8C%E7%97%85_%E6%84%9B%E3%82%BB%E3%83%AA%E3%83%95" data-hatena-bookmark-layout="vertical-balloon" data-hatena-bookmark-lang="ja" title="この記事をはてなブックマークに追加"><img src="https://b.st-hatena.com/images/entry-button/button-only.gif" alt="この記事をはてなブックマークに追加" width="20" height="20" style="border: none;" /></a>
#     </div>
#
#
#
#
#
#     <div class="social-button-item">
#       <a
#           class="entry-share-button entry-share-button-twitter test-share-button-twitter"
#           href="https://x.com/intent/tweet?hashtags=%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86&amp;hashtags=%E3%83%9C%E3%82%A4%E3%82%B9%E3%82%B5%E3%83%B3%E3%83%97%E3%83%AB&amp;text=%E3%80%90%E6%84%9B%E3%82%92%E4%BC%9D%E3%81%88%E3%81%9F%E3%81%84%E5%8E%A8%E4%BA%8C%E7%97%85%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E2%91%A5%E3%80%91%E6%81%8B%E6%84%9B%E3%81%AE%E4%B8%AD%E4%BA%8C%E7%97%85%E3%82%BB%E3%83%AA%E3%83%95+%E7%BD%B0%E3%82%B2%E3%83%BC%E3%83%A0%E3%82%84%E7%B7%B4%E7%BF%92%E3%81%AB%E4%BD%BF%E3%81%84%E3%81%84%E3%81%9F%E3%81%A0%E3%81%91%E3%81%BE%E3%81%99%EF%BC%81+-+%E3%82%B3%E3%82%A8%E3%83%8E%E3%83%9F%E3%82%AB%E3%82%BF%EF%BD%9C%E3%81%AF%E3%82%8B%E3%81%88%E3%82%8B%E3%83%96%E3%83%AD%E3%82%B0&amp;url=https%3A%2F%2Fwww.haruelf.com%2Fentry%2F%25E5%258E%25A8%25E4%25BA%258C%25E7%2597%2585_%25E6%2584%259B%25E3%2582%25BB%25E3%2583%25AA%25E3%2583%2595"
#           title="X（Twitter）で投稿する"
#         ></a>
#     </div>
#
#
#
#     <span>
#       <div class="line-it-button" style="display: none;" data-type="share-e" data-lang="ja" ></div>
#       <script src="//scdn.line-apps.com/n/line_it/thirdparty/loader.min.js" async="async" defer="defer" ></script>
#     </span>
#
#
#
#
# </div>
#
#
#
#     <div class="customized-footer">
#
#   <iframe class="hatena-bookmark-comment-iframe" data-src="https://www.haruelf.com/iframe/hatena_bookmark_comment?canonical_uri=https%3A%2F%2Fwww.haruelf.com%2Fentry%2F%25E5%258E%25A8%25E4%25BA%258C%25E7%2597%2585_%25E6%2584%259B%25E3%2582%25BB%25E3%2583%25AA%25E3%2583%2595" frameborder="0" scrolling="no" style="border: none; width: 100%;">
#   </iframe>
#
#
#
#
#           <div class="entry-footer-modules" id="entry-footer-secondary-modules">
# <div class="hatena-module hatena-module-related-entries" >
#
#   <!-- Hatena-Epic-has-related-entries-with-elasticsearch:true -->
#   <div class="hatena-module-title">
#     関連記事
#   </div>
#   <div class="hatena-module-body">
#     <ul class="related-entries hatena-urllist urllist-with-thumbnails">
#
#
#
#     <li class="urllist-item related-entries-item">
#       <div class="urllist-item-inner related-entries-item-inner">
#
#
#                       <a class="urllist-image-link related-entries-image-link" href="https://www.haruelf.com/entry/fantasyserif0619">
#   <img alt="【異世界セリフ集】ボイスサンプルやセリフ練習・配信等でお使いいただけます。" src="https://cdn.image.st-hatena.com/image/square/7eee579749a6cafc4f4a997629ea8464a7338d1e/backend=imagemagick;height=100;version=1;width=100/https%3A%2F%2Fcdn-ak.f.st-hatena.com%2Fimages%2Ffotolife%2Fh%2Fharukazu1%2F20190730%2F20190730002757.jpg" class="urllist-image related-entries-image" title="【異世界セリフ集】ボイスサンプルやセリフ練習・配信等でお使いいただけます。" width="100" height="100" loading="lazy">
# </a>
#             <div class="urllist-date-link related-entries-date-link">
#   <a href="https://www.haruelf.com/archive/2025/12/03" rel="nofollow">
#     <time datetime="2025-12-02T23:00:00Z" title="2025年12月3日">
#       2025-12-03
#     </time>
#   </a>
# </div>
#
#           <a href="https://www.haruelf.com/entry/fantasyserif0619" class="urllist-title-link related-entries-title-link  urllist-title related-entries-title">【異世界セリフ集】ボイスサンプルやセリフ練習・配信等でお使いいただけます。</a>
#
#
#
#
#
#                       <div class="urllist-entry-body related-entries-entry-body">短い文章は状況や相手を変えるだけで大きく意味合いや言い方が…</div>
#       </div>
#     </li>
#
#
#     <li class="urllist-item related-entries-item">
#       <div class="urllist-item-inner related-entries-item-inner">
#
#
#                       <a class="urllist-image-link related-entries-image-link" href="https://www.haruelf.com/entry/%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%AB/%E7%94%B7%E6%80%A7%E5%90%91%E3%81%91/%E3%82%BB%E3%83%AA%E3%83%95%E5%8F%B0%E6%9C%AC">
#   <img alt="【セリフ集一覧】ジャンル：男性向けセリフ集" src="https://cdn.image.st-hatena.com/image/square/232e5279d54e45e2bc86966c293cc94d8f181751/backend=imagemagick;height=100;version=1;width=100/https%3A%2F%2Fcdn-ak.f.st-hatena.com%2Fimages%2Ffotolife%2Fh%2Fharukazu1%2F20190819%2F20190819172929.jpg" class="urllist-image related-entries-image" title="【セリフ集一覧】ジャンル：男性向けセリフ集" width="100" height="100" loading="lazy">
# </a>
#             <div class="urllist-date-link related-entries-date-link">
#   <a href="https://www.haruelf.com/archive/2025/11/22" rel="nofollow">
#     <time datetime="2025-11-22T04:00:00Z" title="2025年11月22日">
#       2025-11-22
#     </time>
#   </a>
# </div>
#
#           <a href="https://www.haruelf.com/entry/%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%AB/%E7%94%B7%E6%80%A7%E5%90%91%E3%81%91/%E3%82%BB%E3%83%AA%E3%83%95%E5%8F%B0%E6%9C%AC" class="urllist-title-link related-entries-title-link  urllist-title related-entries-title">【セリフ集一覧】ジャンル：男性向けセリフ集</a>
#
#
#
#
#
#                       <div class="urllist-entry-body related-entries-entry-body">男性がいいそうなセリフや演技が好きな人必見のセリフ集一覧で…</div>
#       </div>
#     </li>
#
#
#     <li class="urllist-item related-entries-item">
#       <div class="urllist-item-inner related-entries-item-inner">
#
#
#                       <a class="urllist-image-link related-entries-image-link" href="https://www.haruelf.com/entry/%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%AB/%E5%A5%B3%E6%80%A7%E5%90%91%E3%81%91%E3%82%BB%E3%83%AA%E3%83%95%E5%8F%B0%E6%9C%AC">
#   <img alt="【セリフ集一覧】ジャンル：女性向けセリフ集" src="https://cdn.image.st-hatena.com/image/square/51c872fb219f5a33d2ec78be235c5318d81578ca/backend=imagemagick;height=100;version=1;width=100/https%3A%2F%2Fcdn-ak.f.st-hatena.com%2Fimages%2Ffotolife%2Fh%2Fharukazu1%2F20190819%2F20190819172943.jpg" class="urllist-image related-entries-image" title="【セリフ集一覧】ジャンル：女性向けセリフ集" width="100" height="100" loading="lazy">
# </a>
#             <div class="urllist-date-link related-entries-date-link">
#   <a href="https://www.haruelf.com/archive/2025/05/08" rel="nofollow">
#     <time datetime="2025-05-08T01:13:08Z" title="2025年5月8日">
#       2025-05-08
#     </time>
#   </a>
# </div>
#
#           <a href="https://www.haruelf.com/entry/%E3%82%B8%E3%83%A3%E3%83%B3%E3%83%AB/%E5%A5%B3%E6%80%A7%E5%90%91%E3%81%91%E3%82%BB%E3%83%AA%E3%83%95%E5%8F%B0%E6%9C%AC" class="urllist-title-link related-entries-title-link  urllist-title related-entries-title">【セリフ集一覧】ジャンル：女性向けセリフ集</a>
#
#
#
#
#
#                       <div class="urllist-entry-body related-entries-entry-body">女性がいいそうなセリフや演技が好きな人必見のセリフ集一覧で…</div>
#       </div>
#     </li>
#
#
#     <li class="urllist-item related-entries-item">
#       <div class="urllist-item-inner related-entries-item-inner">
#
#
#                       <a class="urllist-image-link related-entries-image-link" href="https://www.haruelf.com/entry/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E4%B8%80%E8%A6%A7/%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BC/">
#   <img alt="【セリフ集一覧】ジャンル：ファンタジー　" src="https://cdn.image.st-hatena.com/image/square/04309268f180049e5d3db4de19298d2f68c9e59b/backend=imagemagick;height=100;version=1;width=100/https%3A%2F%2Fcdn-ak.f.st-hatena.com%2Fimages%2Ffotolife%2Fh%2Fharukazu1%2F20190819%2F20190819175124.jpg" class="urllist-image related-entries-image" title="【セリフ集一覧】ジャンル：ファンタジー　" width="100" height="100" loading="lazy">
# </a>
#             <div class="urllist-date-link related-entries-date-link">
#   <a href="https://www.haruelf.com/archive/2025/04/26" rel="nofollow">
#     <time datetime="2025-04-26T01:58:03Z" title="2025年4月26日">
#       2025-04-26
#     </time>
#   </a>
# </div>
#
#           <a href="https://www.haruelf.com/entry/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E4%B8%80%E8%A6%A7/%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BC/" class="urllist-title-link related-entries-title-link  urllist-title related-entries-title">【セリフ集一覧】ジャンル：ファンタジー </a>
#
#
#
#
#
#                       <div class="urllist-entry-body related-entries-entry-body">異世界に行きたい人、ファンタジーが好きな人必見のセリフ集一…</div>
#       </div>
#     </li>
#
#
#     <li class="urllist-item related-entries-item">
#       <div class="urllist-item-inner related-entries-item-inner">
#
#
#                       <a class="urllist-image-link related-entries-image-link" href="https://www.haruelf.com/entry/serif/5">
#   <img alt="【厨二病×ファンタジーのセリフ集】中二病セリフ 罰ゲームや練習に使いいただけます！" src="https://cdn.image.st-hatena.com/image/square/9b1af557fc3fd409dce132452bc42fc6b89efa05/backend=imagemagick;height=100;version=1;width=100/https%3A%2F%2Fcdn-ak.f.st-hatena.com%2Fimages%2Ffotolife%2Fh%2Fharukazu1%2F20190719%2F20190719004333.jpg" class="urllist-image related-entries-image" title="【厨二病×ファンタジーのセリフ集】中二病セリフ 罰ゲームや練習に使いいただけます！" width="100" height="100" loading="lazy">
# </a>
#             <div class="urllist-date-link related-entries-date-link">
#   <a href="https://www.haruelf.com/archive/2025/01/13" rel="nofollow">
#     <time datetime="2025-01-12T15:21:42Z" title="2025年1月13日">
#       2025-01-13
#     </time>
#   </a>
# </div>
#
#           <a href="https://www.haruelf.com/entry/serif/5" class="urllist-title-link related-entries-title-link  urllist-title related-entries-title">【厨二病×ファンタジーのセリフ集】中二病セリフ 罰ゲームや練習に使いいただけます！</a>
#
#
#
#
#
#                       <div class="urllist-entry-body related-entries-entry-body">厨二病×ファンタジーのセリフ集です！ 罰ゲームや練習用声の投…</div>
#       </div>
#     </li>
#
# </ul>
#
#   </div>
# </div>
#   </div>
#
#   <div class="entry-footer-html"><a href="https://blogmura.com/ranking.html?p_cid=11002415" target="_blank"><img src="https://b.blogmura.com/88_31.gif" width="88" height="31" border="0" alt="ブログランキング・にほんブログ村へ" />にほんブログ村</a></div>
#
#
#
#     </div>
#
#   <div class="comment-box js-comment-box">
#
#       <a class="leave-comment-title js-leave-comment-title">コメントを書く</a>
#
#     <ul class="comment js-comment">
#       <li class="read-more-comments" style="display: none;"><a>もっと読む</a></li>
#     </ul>
#
#   </div>
#
#   </footer>
#
#   </div>
# </article>
#
#
#
#
#
#
#
#   <!-- rakuten_ad_target_end -->
#   <!-- google_ad_section_end -->
#
#
#
#   <div class="pager pager-permalink permalink">
#
#
#       <span class="pager-prev">
#         <a href="https://www.haruelf.com/entry/2025/04/28/101603" rel="prev">
#           <span class="pager-arrow">&laquo; </span>
#           【ネタバレ注意】マインクラフト／ザ・ム…
#         </a>
#       </span>
#
#
#
#       <span class="pager-next">
#         <a href="https://www.haruelf.com/entry/%E3%82%BB%E3%83%AA%E3%83%95%E9%9B%86%E4%B8%80%E8%A6%A7/%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BC/" rel="next">
#           【セリフ集一覧】ジャンル：ファンタジー
#           <span class="pager-arrow"> &raquo;</span>
#         </a>
#       </span>
#
#   </div>
#
#
#
#
#
#
#         </div>
#       </div>
#
#       <aside id="box1">
#   <div id="box1-inner">
#   </div>
# </aside>
#
#     </div><!-- #wrapper -->
#
#
# <aside id="box2">
#
#   <div id="box2-inner">
#
#
#
# <div class="hatena-module hatena-module-profile">
#   <div class="hatena-module-title">
#     プロフィール
#   </div>
#   <div class="hatena-module-body">
#
#     <a href="https://www.haruelf.com/about" class="profile-icon-link">
#       <img src="https://cdn.profile-image.st-hatena.com/users/harukazu1/profile.png?1639828376"
#       alt="id:harukazu1" class="profile-icon" />
#     </a>
#
#
#
#
#
#       <div class="profile-activities">
#
#         最終更新:
#         <time datetime="2025-12-09T07:00:00Z" data-relative data-epoch="1765263600000" class="updated">2025-12-09 16:00</time>
#
#     </div>
#
#
#
#     <div class="profile-description">
#       <p>はるえるです！セリフ集を作成しています。声優・役者。作った短編台本をボイスサンプルやオーディション原稿に使ってくれたことがきっかけで書くようになりました。ぜひボイスサンプルやセリフ配信などで使ってくれると嬉しいです( *´艸｀)</p>
#
#     </div>
#
#
#
#       <div class="hatena-follow-button-box btn-subscribe js-hatena-follow-button-box"
#
#   >
#
#   <a href="#" class="hatena-follow-button js-hatena-follow-button">
#     <span class="subscribing">
#       <span class="foreground">読者です</span>
# ...
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2020/08" class="archive-module-month-title archive-module-month-2020-8">
#                       2020 / 8
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2020/07" class="archive-module-month-title archive-module-month-2020-7">
#                       2020 / 7
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2020/06" class="archive-module-month-title archive-module-month-2020-6">
#                       2020 / 6
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2020/05" class="archive-module-month-title archive-module-month-2020-5">
#                       2020 / 5
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2020/04" class="archive-module-month-title archive-module-month-2020-4">
#                       2020 / 4
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2020/03" class="archive-module-month-title archive-module-month-2020-3">
#                       2020 / 3
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2020/02" class="archive-module-month-title archive-module-month-2020-2">
#                       2020 / 2
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2020/01" class="archive-module-month-title archive-module-month-2020-1">
#                       2020 / 1
#                     </a>
#                   </li>
#
#               </ul>
#             </li>
#
#             <li class="archive-module-year archive-module-year-hidden" data-year="2019">
#               <div class="archive-module-button">
#                 <span class="archive-module-hide-button">▼</span>
#                 <span class="archive-module-show-button">▶</span>
#               </div>
#               <a href="https://www.haruelf.com/archive/2019" class="archive-module-year-title archive-module-year-2019">
#                 2019
#               </a>
#               <ul class="archive-module-months">
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/12" class="archive-module-month-title archive-module-month-2019-12">
#                       2019 / 12
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/11" class="archive-module-month-title archive-module-month-2019-11">
#                       2019 / 11
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/10" class="archive-module-month-title archive-module-month-2019-10">
#                       2019 / 10
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/09" class="archive-module-month-title archive-module-month-2019-9">
#                       2019 / 9
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/08" class="archive-module-month-title archive-module-month-2019-8">
#                       2019 / 8
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/07" class="archive-module-month-title archive-module-month-2019-7">
#                       2019 / 7
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/06" class="archive-module-month-title archive-module-month-2019-6">
#                       2019 / 6
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/05" class="archive-module-month-title archive-module-month-2019-5">
#                       2019 / 5
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/04" class="archive-module-month-title archive-module-month-2019-4">
#                       2019 / 4
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/03" class="archive-module-month-title archive-module-month-2019-3">
#                       2019 / 3
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/02" class="archive-module-month-title archive-module-month-2019-2">
#                       2019 / 2
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2019/01" class="archive-module-month-title archive-module-month-2019-1">
#                       2019 / 1
#                     </a>
#                   </li>
#
#               </ul>
#             </li>
#
#             <li class="archive-module-year archive-module-year-hidden" data-year="2018">
#               <div class="archive-module-button">
#                 <span class="archive-module-hide-button">▼</span>
#                 <span class="archive-module-show-button">▶</span>
#               </div>
#               <a href="https://www.haruelf.com/archive/2018" class="archive-module-year-title archive-module-year-2018">
#                 2018
#               </a>
#               <ul class="archive-module-months">
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/12" class="archive-module-month-title archive-module-month-2018-12">
#                       2018 / 12
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/11" class="archive-module-month-title archive-module-month-2018-11">
#                       2018 / 11
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/10" class="archive-module-month-title archive-module-month-2018-10">
#                       2018 / 10
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/09" class="archive-module-month-title archive-module-month-2018-9">
#                       2018 / 9
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/08" class="archive-module-month-title archive-module-month-2018-8">
#                       2018 / 8
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/07" class="archive-module-month-title archive-module-month-2018-7">
#                       2018 / 7
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/06" class="archive-module-month-title archive-module-month-2018-6">
#                       2018 / 6
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/05" class="archive-module-month-title archive-module-month-2018-5">
#                       2018 / 5
#                     </a>
#                   </li>
#
#                   <li class="archive-module-month">
#                     <a href="https://www.haruelf.com/archive/2018/02" class="archive-module-month-title archive-module-month-2018-2">
#                       2018 / 2
#                     </a>
#                   </li>
#
#               </ul>
#             </li>
#
#         </ul>
#
#
#   </div>
# </div>
#
#
#
#   </div>
# </aside>
#
#
#   </div>
# </div>
#
#
#
#
#
#
#
#   <div id="bottom-editarea">
#     <script src=”https://ajax.googleapis.com/ajax/libs/jquery/3.1.0/jquery.min.js“></script>
# <script src=”https://hatena.wackwack.net/v1.1/js/breadcrumb.min.js“></script>
# <script src=”https://hatena.wackwack.net/v1.1/js/category_archive.min.js“></script>
# <div style="text-align: center">
# <iframe src="https://rcm-fe.amazon-adsystem.com/e/cm?o=9&p=293&l=ur1&category=echostudio&banner=1FRWCJMTGVQQBW8E0GR2&f=ifr&linkID=836b1f3a1e5d433ae1aa582313c479d6&t=haruelf-22&tracking_id=haruelf-22" width="640" height="100" scrolling="no" border="0" marginwidth="0" style="border:none;" frameborder="0" sandbox="allow-scripts allow-same-origin allow-popups allow-top-navigation-by-user-activation"></iframe>
# </div>
# <p> </p>
# <p style="text-align: center;"><a href="https://www.tokyo-anime.jp/subject/voice.html" target="_blank"><img src="https://cdn-ak.f.st-hatena.com/images/fotolife/h/harukazu1/20250401/20250401134930.jpg" width="359" height="112" loading="lazy" title="" class="hatena-fotolife" itemprop="image" /></a></p>
# <p> </p>
#   </div>
#
#
#     </div>
#   </div>
#
# <footer id="footer" data-brand="hatenablog">
#   <div id="footer-inner">
#
#       <div style="display:none !important" class="guest-footer js-guide-register test-blogs-register-guide" data-action="guide-register">
#   <div class="guest-footer-content">
#     <h3>はてなブログをはじめよう！</h3>
#     <p>harukazu1さんは、はてなブログを使っています。あなたもはてなブログをはじめてみませんか？</p>
#     <div class="guest-footer-btn-container">
#       <div  class="guest-footer-btn">
#         <a class="btn btn-register js-inherit-ga" href="https://blog.hatena.ne.jp/register?via=200227" target="_blank">はてなブログをはじめる（無料）</a>
#       </div>
#       <div  class="guest-footer-btn">
#         <a href="https://hatena.blog/guide" target="_blank">はてなブログとは</a>
#       </div>
#     </div>
#   </div>
# </div>
#
#
#     <address class="footer-address">
#       <a href="https://www.haruelf.com/">
#         <img src="https://cdn.image.st-hatena.com/image/square/ca4a2edd1613bae586d27eae91080e3945cd9458/backend=imagemagick;height=128;version=1;width=128/https%3A%2F%2Fcdn.user.blog.st-hatena.com%2Fblog_custom_icon%2F151169385%2F1747663642437164" width="16" height="16" alt="コエノミカタ｜はるえるブログ"/>
#         <span class="footer-address-name">コエノミカタ｜はるえるブログ</span>
#       </a>
#     </address>
#     <p class="services">
#       Powered by <a href="https://hatena.blog/">Hatena Blog</a>
#       |
#         <a href="https://blog.hatena.ne.jp/-/abuse_report?target_url=https%3A%2F%2Fwww.haruelf.com%2Fentry%2F%25E5%258E%25A8%25E4%25BA%258C%25E7%2597%2585_%25E6%2584%259B%25E3%2582%25BB%25E3%2583%25AA%25E3%2583%2595" class="report-abuse-link test-report-abuse-link" target="_blank">ブログを報告する</a>
#     </p>
#   </div>
# </footer>
#
#
#
#   <script async src="https://s.hatena.ne.jp/js/widget/star.js"></script>
#
#
#   <script>
#     if (typeof window.Hatena === 'undefined') {
#       window.Hatena = {};
#     }
#     if (!Hatena.hasOwnProperty('Star')) {
#       Hatena.Star = {
#         VERSION: 2,
#       };
#     }
#   </script>
#
#
#
#
#
# <div class="quote-box">
#   <div class="tooltip-quote tooltip-quote-stock">
#     <i class="blogicon-quote" title="引用をストック"></i>
#   </div>
#   <div class="tooltip-quote tooltip-quote-tweet js-tooltip-quote-tweet">
#     <a class="js-tweet-quote" target="_blank" data-track-name="quote-tweet" data-track-once>
#       <img src="https://cdn.blog.st-hatena.com/images/admin/quote/quote-x-icon.svg?version=abf96f4605410ec3d67a4284c01b45" title="引用して投稿する" >
#     </a>
#   </div>
# </div>
#
# <div class="quote-stock-panel" id="quote-stock-message-box" style="position: absolute; z-index: 3000">
#   <div class="message-box" id="quote-stock-succeeded-message" style="display: none">
#     <p>引用をストックしました</p>
#     <button class="btn btn-primary" id="quote-stock-show-editor-button" data-track-name="curation-quote-edit-button">ストック一覧を見る</button>
#     <button class="btn quote-stock-close-message-button">閉じる</button>
#   </div>
#
#   <div class="message-box" id="quote-login-required-message" style="display: none">
#     <p>引用するにはまずログインしてください</p>
#     <button class="btn btn-primary" id="quote-login-button">ログイン</button>
#     <button class="btn quote-stock-close-message-button">閉じる</button>
#   </div>
#
#   <div class="error-box" id="quote-stock-failed-message" style="display: none">
#     <p>引用をストックできませんでした。再度お試しください</p>
#     <button class="btn quote-stock-close-message-button">閉じる</button>
#   </div>
#
#   <div class="error-box" id="unstockable-quote-message-box" style="display: none; position: absolute; z-index: 3000;">
#     <p>限定公開記事のため引用できません。</p>
#   </div>
# </div>
#
# <script type="x-underscore-template" id="js-requote-button-template">
#   <div class="requote-button js-requote-button">
#     <button class="requote-button-btn tipsy-top" title="引用する"><i class="blogicon-quote"></i></button>
#   </div>
# </script>
#
#
#
#
#   <div id="hidden-subscribe-button" style="display: none;">
#     <div class="hatena-follow-button-box btn-subscribe js-hatena-follow-button-box"
#
#   >
#
#   <a href="#" class="hatena-follow-button js-hatena-follow-button">
#     <span class="subscribing">
#       <span class="foreground">読者です</span>
#       <span class="background">読者をやめる</span>
#     </span>
#     <span class="unsubscribing" data-track-name="profile-widget-subscribe-button" data-track-once>
#       <span class="foreground">読者になる</span>
#       <span class="background">読者になる</span>
#     </span>
#   </a>
#   <div class="subscription-count-box js-subscription-count-box">
#     <i></i>
#     <u></u>
#     <span class="subscription-count js-subscription-count">
#     </span>
#   </div>
# </div>
#
#   </div>
#
#
#
#
#
#
#
#
#   <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#
# <script src="https://b.st-hatena.com/js/bookmark_button.js" charset="utf-8" async="async"></script>
#
#
# <script type="text/javascript" src="https://cdn.blog.st-hatena.com/js/external/jquery.min.js?v=1.12.4&amp;version=abf96f4605410ec3d67a4284c01b45"></script>
#
#
#
#
#
#
#
# <script src="https://cdn.blog.st-hatena.com/js/texts-ja.js?version=abf96f4605410ec3d67a4284c01b45"></script>
#
#
#
#   <script id="vendors-js" data-env="production" src="https://cdn.blog.st-hatena.com/js/vendors.js?version=abf96f4605410ec3d67a4284c01b45" crossorigin="anonymous"></script>
#
# <script id="hatenablog-js" data-env="production" src="https://cdn.blog.st-hatena.com/js/hatenablog.js?version=abf96f4605410ec3d67a4284c01b45" crossorigin="anonymous" data-page-id="entry"></script>
#
#
#   <script>Hatena.Diary.GlobalHeader.init()</script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   </body>
# </html>

# %%
html = response.text

root = lxml.html.fromstring(html)
content = root.xpath('//div[contains(@class, "entry-content")]')[0]

lines = []

# id が数字で始まる h3（1〜50）だけ対象
h3_list = content.xpath(
    './/h3[re:test(@id, "^[0-9]+")]',
    namespaces={"re": "http://exslt.org/regular-expressions"}
)

for h3 in h3_list:
    texts = []

    for elem in h3.itersiblings():
        if elem.tag == "h3":
            break
        if elem.tag != "p":
            continue

        # style付きの p は除外
        if elem.get("style"):
            continue

        text = ''.join(elem.itertext()).strip()
        if not text:
            continue

        # ================= 不要部分の除去 =================

        # 1) 広告スクリプト行は丸ごと捨てる
        if "adsbygoogle" in text:
            continue

        # 2) 「訳：〜」が入っている行は訳だとみなして捨てる
        if "訳：" in text:
            continue

        # 3) 括弧だけの注釈行を捨てる
        if (text.startswith("（") and text.endswith("）")) or \
           (text.startswith("(") and text.endswith(")")):
            continue

        # 4) 「使い方:」「【俺様系のセリフ集①】」以降は説明なので切り落とす
        cut_words = ["使い方:", "【俺様系のセリフ集①】"]
        for w in cut_words:
            if w in text:
                text = text.split(w)[0].strip()

        # 5) 記事末尾の宣伝ブロックのキーワードを削る
        trash_words = [
            "🎤セリフ練習におすすめ",
            "🎙ナレーション練習におすすめ",
            "🗣 滑舌・発声トレーニング向け",
            "🎹声劇台本（※２名以上の台本もこちら）",
            "🎧業界用語を知りたい方におすすめ",
            "🖊オーディション対策におすすめ！",
            "最後までご覧いただきありがとうございました！",
            "気になる記事があればぜひ読んでみてくださいね✨",
            "はてなブログさんのランキングにも参加しています！",
            "⇓クリックで応援お願いします！"
        ]
        for w in trash_words:
            text = text.replace(w, "")
        text = text.strip()

        # ここまでやって空になったらスキップ
        if not text:
            continue
        # ==============================================

        texts.append(text)

    lines.append(''.join(texts))

# 結果確認
# print(len(lines), "行取得")
for line in lines:
    print(line)
# Out:
# この身が朽ち果てようとも、君の事を永遠（とわ）に護る──それが俺の“契約”だ。
# 愛している、なんて言葉じゃ足りない。俺の魂ごと貴様に捧げよう。
# 一途な心は、時に世界をも変える。お前、あいつを絶対に幸福にするんんだな。愛に全力を注げ。
# 生まれ変わっても、運命に逆らったとしても、俺はまた君を選ぶ。どうか生きてくれ。
# そんな悲しい運命なんて俺が撃ち砕く。共に行こう。さぁ手を。
# …そうか、それがあなたの選んだ選択か。ならば、俺はもう干渉しない。だが常にあなたの味方だ。困った時があればいつでも言ってくれ。
# ありがとう。ほんの少しでも、俺を見てくれたことに感謝する。
# 君がいない世界なんて、色を失った幻想だ。俺はこれからどうしたらいいんだ...なぁ答えてくれ...よ
# 俺の役目は...見届けることだ。あの美しい心を手にするその“瞬間”を。
# 俺の心が叫んでいるんだ！最高のエンディングをむかえろと！立て！まだ君はチャレンジしていないんだ！
# ジレンマがある。恋人がほしい奴に、恋人は出来ない。まずは己の目標や夢に向けて全力で努力せよ。つまりやることをちゃんとやれ。アプローチをするのはそれからだ。
# 心がざわめく。この感情は何だ。求めていたもの、握るべきは栄光のはず。なんだ？この感情は...！！！
# 貴様の行いに一度だけ、目をつぶり、俺は静かに見守る。決して、邪魔はしないと誓う。だが一度きりだ。
# 一途な心は、時に世界をも変える。その想いが本物なら大丈夫であろう。もし偽りなら、その後に待っているのは破滅だ。
# 慣れは恐怖だ。大切な物なら大切にしまっておけ。人は失ってからその大切さに気付く。貴様は...後悔したいのか？

# %%
output_path = "【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ.txt"

with open(output_path, mode="w", encoding="utf-8") as f:
    for line in lines:
        f.write(line + "\n")

print(f"{len(lines)} 行を書き込みました → {output_path}")
# Out:
# 15 行を書き込みました → 【愛を伝えたい厨二病セリフ集⑥】恋愛の中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ.txt
