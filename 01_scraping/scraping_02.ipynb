# %%
# !pip install requests
# !pip install lxml

# %%
import requests
import lxml.html

# %%
url = "https://www.haruelf.com/entry/2019/09/05/012327"
response = requests.get(url)

response.encoding = response.apparent_encoding

print(response.text)
# Out:
# <!DOCTYPE html>
# <html
#   lang="ja"
#
# data-admin-domain="//blog.hatena.ne.jp"
# data-admin-origin="https://blog.hatena.ne.jp"
# data-author="harukazu1"
# data-avail-langs="ja en"
# data-blog="harukazu1.hatenablog.com"
# data-blog-comments-top-is-new="1"
# data-blog-host="harukazu1.hatenablog.com"
# data-blog-is-public="1"
# data-blog-name="コエノミカタ｜はるえるブログ"
# data-blog-owner="harukazu1"
# data-blog-show-ads=""
# data-blog-show-sleeping-ads=""
# data-blog-uri="https://www.haruelf.com/"
# data-blog-uuid="17391345971616627328"
# data-blogs-uri-base="https://www.haruelf.com"
# data-brand="pro"
# ...

# %%
html = response.text

root = lxml.html.fromstring(html)
content = root.xpath('//div[contains(@class, "entry-content")]')[0]

lines = []

# id が数字で始まる h3（1〜50）だけ対象
h3_list = content.xpath(
    './/h3[re:test(@id, "^[0-9]+")]',
    namespaces={"re": "http://exslt.org/regular-expressions"}
)

for h3 in h3_list:
    texts = []

    for elem in h3.itersiblings():
        if elem.tag == "h3":
            break
        if elem.tag != "p":
            continue

        # style付きの p は除外
        if elem.get("style"):
            continue

        text = ''.join(elem.itertext()).strip()
        if not text:
            continue

        # ================= 不要部分の除去 =================

        # 1) 広告スクリプト行は丸ごと捨てる
        if "adsbygoogle" in text:
            continue

        # 2) 「訳：〜」が入っている行は訳だとみなして捨てる
        if "訳：" in text:
            continue

        # 3) 括弧だけの注釈行を捨てる
        if (text.startswith("（") and text.endswith("）")) or \
           (text.startswith("(") and text.endswith(")")):
            continue

        # 4) 「使い方:」「【俺様系のセリフ集①】」以降は説明なので切り落とす
        cut_words = ["使い方:", "【俺様系のセリフ集①】"]
        for w in cut_words:
            if w in text:
                text = text.split(w)[0].strip()

        # 5) 記事末尾の宣伝ブロックのキーワードを削る
        trash_words = [
            "🎤セリフ練習におすすめ",
            "🎙ナレーション練習におすすめ",
            "🗣 滑舌・発声トレーニング向け",
            "🎹声劇台本（※２名以上の台本もこちら）",
            "🎧業界用語を知りたい方におすすめ",
            "🖊オーディション対策におすすめ！",
            "最後までご覧いただきありがとうございました！",
            "気になる記事があればぜひ読んでみてくださいね✨",
            "はてなブログさんのランキングにも参加しています！",
            "⇓クリックで応援お願いします！"
        ]
        for w in trash_words:
            text = text.replace(w, "")
        text = text.strip()

        # ここまでやって空になったらスキップ
        if not text:
            continue
        # ==============================================

        texts.append(text)

    lines.append(''.join(texts))

# 結果確認
# print(len(lines), "行取得")
for line in lines:
    print(line)
# Out:
# 「我はついにここから旅立つのだ。皆、感謝する。それぞれが栄光の地へと旅立つだろう。それを私は楽しみにしているぞ」
# 「世界が凍っていく。我は衣（ころも）を所望するぞ。なんだと？我が衣（ころも）を取らなきゃならないのか？」
# 「火の神が舞い降りた。氷の神が去った今...私たちはただ耐えるしか無い...なに？！風の神の思し召しが...嬉しいぞ！」
# 「太陽の神が舞い降りた季節。俺の休みは今日までだ...俺に課（か）された試練は多く残っている。今夜、俺は闇の住人になる。」
# 「このままじゃあ俺がお前の知っている俺じゃなくなってしまう...その前にこれを託したい。また会える日を楽しみにしている」
# 「この世界は腐ってる。お前は世界の腐敗に関わってしまった。だから世界の修復を手伝え。」
# 「私は万能なんだ...だからあなたの為にこれを作ってきた。これは私しか作れないものなんだ。私は選ばれし存在だ！」
# 「それは残像だ...お前の攻撃当たるわけがなかろう？」
# 「この中に俺の氷菓を捕食した犯人がいる。誰だ出てこい！！今出るのなら許してやろう...しかし今出ないなら後悔の渦にのまれて沈め！！
# 「皆さんどうしました？俺なんかやっちゃいました？俺の力強すぎました？あっはー流石俺っすわ！」
# 「そんなに大声で吠えるな？弱く見えるぞ？」
# 「僕たちは迷いつつも探し求めている。いつか輝くために...悲しみや涙も力に変える...そうして強くなっていくんだ」
# 「明日からは別々の道。そんな突然心の準備が出来ていない！！でも諦めるしかないんだ...さよならgood-bye」
# 「儚き日々を力に変えて、解き放て『星屑の衝撃〔スターダストインパクト〕』」
# 「見栄だけの 迷惑な上司に鉄槌を！！『仕事の放棄〔オールストライキ！！〕』」
# 「人間の本質ってのはどうしても闇なんだよ。人は闇の中で生まれ、光に向かい進んでいく。つまり闇なんだ。これがわかるようになったなら君も真理に１つ近づいたってことだね」
# 「それが神が決めた運命ってことなら俺はいくらだって抗（あらが）ってみせる。俺は必ずお前を助けるんだ。今向かっている！それまで持ちこたえてくれ」
# 「本気を見せる時が来たようだね。一度しか見せないから見逃すなよ？」
# ...

# %%
output_path = "【厨二病系のセリフ集②】中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ.txt"

with open(output_path, mode="w", encoding="utf-8") as f:
    for line in lines:
        f.write(line + "\n")

print(f"{len(lines)} 行を書き込みました → {output_path}")
# Out:
# 30 行を書き込みました → 【厨二病系のセリフ集②】中二病セリフ 罰ゲームや練習に使いいただけます！ - コエノミカタ｜はるえるブログ.txt
